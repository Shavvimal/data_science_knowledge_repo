# %%
import pandas as pd
import numpy as np
data = pd.read_csv('./final_preprocessed_Data_no_STG.csv')

# %%
data
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 0                 0  5V01  AL19550015VAL4A00       1  2021-03-01        25
# 1                 1  5V24  AP21560017TC2SA00       0  2021-03-01        25
# 2                 3  5V06  AP26545021WWPPA02       0  2019-07-01         5
# 3                 8  5V13  AL26560018HHT2A00       0  2020-06-01        16
# 4                10  5V01  AP20555017VSN5AQ0       0  2020-10-01        20
# ...             ...   ...                ...     ...         ...       ...
# 1269211     2961491  5V16  AP23540019YUSAA02       0  2021-08-01        30
# 1269212     2961494  5V30  AP23540019YUSAA02       0  2020-09-01        19
# 1269213     2961497  5V32  AP25555020VWPPA02       0  2021-04-01        26
# 1269214     2961499  5V27  AP25555019WQT5A02       0  2021-03-01        25
# 1269215     2961500  5V18  AP18565015TTT2A00       0  2021-02-01        24
#
# ...

# %% [markdown]
# Removes timeseries where all Volumes are 0

# %%
data["volume_by_material"] = data.groupby(["time_idx", "Material"], observed=True).Volume.transform("sum")

# %%
data
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 0                 0  5V01  AL19550015VAL4A00       1  2021-03-01        25
# 1                 1  5V24  AP21560017TC2SA00       0  2021-03-01        25
# 2                 3  5V06  AP26545021WWPPA02       0  2019-07-01         5
# 3                 8  5V13  AL26560018HHT2A00       0  2020-06-01        16
# 4                10  5V01  AP20555017VSN5AQ0       0  2020-10-01        20
# ...             ...   ...                ...     ...         ...       ...
# 1269211     2961491  5V16  AP23540019YUSAA02       0  2021-08-01        30
# 1269212     2961494  5V30  AP23540019YUSAA02       0  2020-09-01        19
# 1269213     2961497  5V32  AP25555020VWPPA02       0  2021-04-01        26
# 1269214     2961499  5V27  AP25555019WQT5A02       0  2021-03-01        25
# 1269215     2961500  5V18  AP18565015TTT2A00       0  2021-02-01        24
#
# ...

# %%
data2 = data[data.groupby(["timeseries"], observed=True).Volume.transform("mean") != 0]

# %%
data.groupby(["timeseries"], observed=True).Volume.transform("mean")
# Out:
# 0          16.277778
# 1           0.000000
# 2           0.000000
# 3           0.111111
# 4           0.000000
#              ...
# 1269211     0.166667
# 1269212     2.111111
# 1269213     0.000000
# 1269214     7.444444
# 1269215     6.333333
# Name: Volume, Length: 1269216, dtype: float64

# %%
data2.groupby(["timeseries"], observed=True).Volume.transform("mean")
# Out:
# 0          16.277778
# 3           0.111111
# 5           1.972222
# 6           1.888889
# 7           0.055556
#              ...
# 1269210    14.611111
# 1269211     0.166667
# 1269212     2.111111
# 1269214     7.444444
# 1269215     6.333333
# Name: Volume, Length: 724680, dtype: float64

# %%
data2
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 0                 0  5V01  AL19550015VAL4A00       1  2021-03-01        25
# 3                 8  5V13  AL26560018HHT2A00       0  2020-06-01        16
# 5                11  5V18  AP17565015TWTRA00       0  2019-10-01         8
# 6                13  5V07  AL18570014TAW4A00       0  2020-07-01        17
# 7                14  5V32  AL19560015HAA4A00       0  2020-09-01        19
# ...             ...   ...                ...     ...         ...       ...
# 1269210     2961490  5V35  AP22560017VQT5A00       0  2020-02-01        12
# 1269211     2961491  5V16  AP23540019YUSAA02       0  2021-08-01        30
# 1269212     2961494  5V30  AP23540019YUSAA02       0  2020-09-01        19
# 1269214     2961499  5V27  AP25555019WQT5A02       0  2021-03-01        25
# 1269215     2961500  5V18  AP18565015TTT2A00       0  2021-02-01        24
#
# ...

# %% [markdown]
# Filter to last 6 indexes

# %%
data_last_6_idx = data2.loc[data2['time_idx'].isin([30, 31, 32, 33, 34])]

# %%
data_last_6_idx
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 11               23  5V18  AL14580013TAW4A00       0  2021-08-01        30
# 20               38  5V01  AP21560016TCMTA00       0  2021-09-01        31
# 46              101  5V31  AP18555015VSP5A00       0  2021-10-01        32
# 50              110  5V11  AL22555017VAXWA02       0  2021-09-01        31
# 52              116  5V36  AP21565015HQT5A00       0  2021-08-01        30
# ...             ...   ...                ...     ...         ...       ...
# 1269194     2961460  5V01  AP21560016VQT6A02       0  2022-01-01        35
# 1269200     2961474  5V27  AL18565014TAM4A00       0  2021-08-01        30
# 1269202     2961481  5V11  AP22555016VWXSA02       0  2021-10-01        32
# 1269205     2961485  5V18  AP23560018WQT5A02       0  2021-10-01        32
# 1269211     2961491  5V16  AP23540019YUSAA02       0  2021-08-01        30
#
# ...

# %%
data[data.groupby(["timeseries"], observed=True).Volume.transform("min") != 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Plant, Material, Volume, Date, time_idx, month, log_volume, avg_volume_by_material, avg_volume_by_plant, timeseries]
# Index: []

# %%
data.loc[data['time_idx'].isin([34])][data.loc[data['time_idx'].isin([34])].groupby(["timeseries"], observed=True).Volume.transform("min") != 0]
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 66              141  5V21  AP19555016HWTRA00       8  2021-12-01        34
# 70              156  5V36  AP22550018VWPRA02      15  2021-12-01        34
# 77              170  5M01  AP29530020YUVPA02      28  2021-12-01        34
# 200             455  5V01  AP24535020YQPRA02       4  2021-12-01        34
# 263             599  5V35  AP21560016VHTRA00      31  2021-12-01        34
# ...             ...   ...                ...     ...         ...       ...
# 1268160     2959058  5V21  AP18570013TQT5A00       2  2021-12-01        34
# 1268326     2959421  5V35  AP23555018VHTRA00      17  2021-12-01        34
# 1268542     2959957  5V13  AP22545017YULAA02       4  2021-12-01        34
# 1268783     2960487  5V36  AP23555017YQPRA02      29  2021-12-01        34
# 1269092     2961179  5V36  AP22545018YQPRA02      24  2021-12-01        34
#
# ...

# %%
data2 = data[data.groupby(["timeseries"], observed=True).Volume.transform("mean") != 0]

timeseries_to_keep = data_last_5_idx.loc[data_last_5_idx['Volume'].isin([0]) == False]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SHAV~1.VIM\AppData\Local\Temp/ipykernel_27628/2211484208.py in <module>
#       1 #data2 = data[data.groupby(["timeseries"], observed=True).Volume.transform("mean") != 0]
#       2
# ----> 3 timeseries_to_keep = data_last_5_idx.loc[data_last_5_idx.groupby(["timeseries"], observed=True)['Volume'].isin([0]) == False]
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'isin'

# %%
timeseries_to_keep.loc[timeseries_to_keep['time_idx'].isin([30, 31, 32, 33, 34, 35])]["Volume"].min()
# Out:
# 1

# %%
list_timerseries_to_keep = timeseries_to_keep['timeseries'].unique()

# %%
list_timerseries_to_keep
# Out:
# array([   67,    71,    78, ..., 28439, 16939, 16132], dtype=int64)

# %%
filtered = data2.loc[data2['timeseries'].isin(list_timerseries_to_keep)]

# %%
# THIS SHOULD NOT BE 0
filtered.loc[filtered['time_idx'].isin([30, 31, 32, 33, 34, 35])]["Volume"].min()
# Out:
# 0

# %%
data3[data3.groupby(["timeseries"], observed=True).Volume.transform("mean") != 0]
# Out:
#   File "C:\Users\SHAV~1.VIM\AppData\Local\Temp/ipykernel_27628/642827704.py", line 1
#     data3[data3.groupby(["timeseries"], observed=True).Volume isin 0]
#                                                               ^
# SyntaxError: invalid syntax

# %%
timeseries_to_keep
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 50              110  5V11  AL22555017VAXWA02       0  2021-09-01        31
# 52              116  5V36  AP21565015HQT5A00       0  2021-08-01        30
# 54              118  5V01  AP25540022YWPRA02       0  2021-10-01        32
# 57              126  5V11  AP22555017HC2SA00       0  2021-10-01        32
# 66              141  5V21  AP19555016HWTRA00       8  2021-12-01        34
# ...             ...   ...                ...     ...         ...       ...
# 1269119     2961269  5M01  AP20560015VQT5A00       9  2021-08-01        30
# 1269121     2961283  5M01  AP18565015VSP5AA2      21  2021-09-01        31
# 1269127     2961293  5V35  AP22560018VWPRA02      24  2021-09-01        31
# 1269144     2961332  5V31  AP22545019VWPRA02       0  2022-01-01        35
# 1269194     2961460  5V01  AP21560016VQT6A02       0  2022-01-01        35
#
# ...

# %%
timeseries_to_keep.groupby(["timeseries"], observed=True).Volume.transform("mean")
# Out:
# 50          3.500000
# 52          2.000000
# 54          0.666667
# 57          1.000000
# 66         14.333333
#              ...
# 1269119    66.000000
# 1269121    93.666667
# 1269127     6.000000
# 1269144     0.666667
# 1269194    53.333333
# Name: Volume, Length: 59196, dtype: float64

# %%
arr_good_timeseries = any_zeroes['timeseries'].unique()

# %%
final_data = data2.loc[data2['timeseries'].isin(arr_good_timeseries)]

# %%
final_data = data2.loc[data2['timeseries'].isin(list(set(timeseries_to_keep["timeseries"])))]

# %%
final_data.groupby(["timeseries"], observed=True).Volume.transform("mean").min()
# Out:
# 0.027777777777777776

# %%
final_data.loc[data2['time_idx'].isin([30, 31, 32, 33, 34, 35])].groupby(["timeseries"], observed=True).Volume.transform("mean").min()
# Out:
# 0.16666666666666666

# %%
data.loc[data['time_idx'].isin([30, 31, 32, 33, 34, 35])].groupby(["timeseries"], observed=True).Volume.transform("mean") == 0

# %%
timeseries_drop = data.loc[data['time_idx'].isin([30, 31, 32, 33, 34, 35])][data.loc[data['time_idx'].isin([30, 31, 32, 33, 34, 35])].groupby(["timeseries"], observed=True).Volume.transform("mean") == 0]

# %%
timeseries_drop
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  time_idx  \
# 11               23  5V18  AL14580013TAW4A00       0  2021-08-01        30
# 20               38  5V01  AP21560016TCMTA00       0  2021-09-01        31
# 24               47  5500  AP20565016TC2WA00       0  2021-09-01        31
# 36               70  5V10  AP23545017YULSA00       0  2022-01-01        35
# 46              101  5V31  AP18555015VSP5A00       0  2021-10-01        32
# ...             ...   ...                ...     ...         ...       ...
# 1269200     2961474  5V27  AL18565014TAM4A00       0  2021-08-01        30
# 1269202     2961481  5V11  AP22555016VWXSA02       0  2021-10-01        32
# 1269205     2961485  5V18  AP23560018WQT5A02       0  2021-10-01        32
# 1269208     2961488  5V24  AP25555018VWPPA02       0  2022-01-01        35
# 1269211     2961491  5V16  AP23540019YUSAA02       0  2021-08-01        30
#
# ...

# %%
list_to_drop = list(set(timeseries_drop["timeseries"]))

# %%
list_to_drop
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  7,
#  8,
#  10,
#  11,
#  12,
#  14,
#  15,
#  18,
#  19,
#  20,
#  21,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  31,
#  32,
#  33,
#  37,
#  39,
#  40,
#  41,
#  43,
#  44,
#  45,
#  46,
#  47,
#  48,
#  50,
#  52,
#  56,
#  57,
#  59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  68,
#  69,
#  70,
#  72,
#  73,
#  74,
#  76,
#  77,
#  79,
#  81,
#  83,
#  84,
#  85,
#  87,
#  88,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  97,
#  98,
#  99,
#  100,
#  102,
#  103,
#  105,
#  106,
#  107,
#  108,
#  109,
#  113,
#  114,
#  115,
#  116,
#  119,
#  120,
#  122,
#  126,
#  127,
#  128,
#  130,
#  131,
#  132,
#  133,
#  135,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  145,
#  146,
#  147,
#  149,
#  150,
#  151,
#  153,
#  154,
#  155,
#  157,
#  161,
#  162,
#  164,
#  165,
#  166,
#  167,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  176,
#  177,
#  178,
#  180,
#  182,
#  183,
#  189,
#  190,
#  191,
#  192,
#  193,
# ...

# %%
data["timeseries"].isin(list_to_drop)
# Out:
# 0           True
# 3           True
# 5          False
# 6           True
# 7           True
#            ...
# 1269210    False
# 1269211     True
# 1269212    False
# 1269214     True
# 1269215     True
# Name: timeseries, Length: 724680, dtype: bool

# %%
data.drop(data["timeseries"].isin(list_to_drop))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SHAV~1.VIM\AppData\Local\Temp/ipykernel_27628/1877999957.py in <module>
# ----> 1 data.drop(data["timeseries"].isin(list_to_drop))
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
data = data.loc[data["timeseries"].isin(list_to_drop) == False]

# %%
final_data.to_csv('final_preprocessed_Data_removed_zeroes_atempt_4.csv')
