# %%
import pandas as pd
import numpy as np
data = pd.read_csv('./dataexport2.csv')

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 0            2022-01-01  AI15570013TARCA20  5M01              510
# 1            2022-01-01  AI15570013TARCA20  5M01              510
# 2            2022-01-01  AI15570013TARCA20  5M01              510
# 3            2022-01-01  AI15570013TARCA20  5M01              510
# 4            2022-01-01  AI15570013TARCA20  5M01              510
# ...                 ...                ...   ...              ...
# 17181019     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17181020     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17181021     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17181022     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17181023     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff    FieldID                 Field  \
# 0           2019-02-01         -35     ACTSLS       SalesYearMinus3
# ...

# %%
data = data.loc[data['FieldID'] == 'ACTSLS']

# %%
data.drop('FieldID', axis=1, inplace=True)
data.drop('Field', axis=1, inplace=True)
data.rename(columns={'FieldContent':'Volume'}, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\shav.vimelindiran\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 0            2022-01-01  AI15570013TARCA20  5M01              510
# 1            2022-01-01  AI15570013TARCA20  5M01              510
# 2            2022-01-01  AI15570013TARCA20  5M01              510
# 3            2022-01-01  AI15570013TARCA20  5M01              510
# 4            2022-01-01  AI15570013TARCA20  5M01              510
# ...                 ...                ...   ...              ...
# 17180971     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180972     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180973     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180974     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180975     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff  Volume UpdateBy  \
# 0           2019-02-01         -35       0    Macro
# 1           2019-03-01         -34       0    Macro
# ...

# %%
def prCyan(skk): print("\033[96m {}\033[00m" .format(skk))

def uniques(category):    
    category_counts = data[category].value_counts()
    print("The number of unique values in column \"" + str(category) + "\" is: ", end = '')
    prCyan(str(len(category_counts)))
    category_counts.plot(kind='bar')
    return category_counts

# %%
uniques("Material")
# Out:
# The number of unique values in column "Material" is:  5877

# %%
uniques("Plant")
# Out:
# The number of unique values in column "Plant" is:  32

# %%
data.columns
# Out:
# Index(['PlanningPeriod', 'Material', 'Plant', 'SalesTargetGroup',
#        'PlannedPeriod', 'PeriodDiff', 'Volume', 'UpdateBy', 'UpdateWhen'],
#       dtype='object')

# %%
uniques("UpdateBy")
# Out:
# The number of unique values in column "UpdateBy" is:  1

# %%
data.drop('UpdateBy', axis=1, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.columns
# Out:
# Index(['PlanningPeriod', 'Material', 'Plant', 'SalesTargetGroup',
#        'PlannedPeriod', 'PeriodDiff', 'Volume', 'UpdateWhen'],
#       dtype='object')

# %%
uniques("UpdateWhen")
# Out:
# The number of unique values in column "UpdateWhen" is:  1

# %%
data.drop('UpdateWhen', axis=1, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 0            2022-01-01  AI15570013TARCA20  5M01              510
# 1            2022-01-01  AI15570013TARCA20  5M01              510
# 2            2022-01-01  AI15570013TARCA20  5M01              510
# 3            2022-01-01  AI15570013TARCA20  5M01              510
# 4            2022-01-01  AI15570013TARCA20  5M01              510
# ...                 ...                ...   ...              ...
# 17180971     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180972     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180973     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180974     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 17180975     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff  Volume
# 0           2019-02-01         -35       0
# 1           2019-03-01         -34       0
# ...

# %%
uniques("PlanningPeriod")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PlanningPeriod'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.drop('PlanningPeriod', axis=1, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data
# Out:
#                    Material Plant SalesTargetGroup PlannedPeriod  PeriodDiff  \
# 0         AI15570013TARCA20  5M01              510    2019-02-01         -35
# 1         AI15570013TARCA20  5M01              510    2019-03-01         -34
# 2         AI15570013TARCA20  5M01              510    2019-04-01         -33
# 3         AI15570013TARCA20  5M01              510    2019-05-01         -32
# 4         AI15570013TARCA20  5M01              510    2019-06-01         -31
# ...                     ...   ...              ...           ...         ...
# 17180971  TT38652264TT3RTA0  5V21              5A4    2021-09-01          -4
# 17180972  TT38652264TT3RTA0  5V21              5A4    2021-10-01          -3
# 17180973  TT38652264TT3RTA0  5V21              5A4    2021-11-01          -2
# 17180974  TT38652264TT3RTA0  5V21              5A4    2021-12-01          -1
# 17180975  TT38652264TT3RTA0  5V21              5A4    2022-01-01           0
#
#           Volume
# 0              0
# ...

# %%
cols = data.columns.tolist()

# %%
cols
# Out:
# ['Material',
#  'Plant',
#  'SalesTargetGroup',
#  'PlannedPeriod',
#  'PeriodDiff',
#  'Volume']

# %%
cols = [
    'Plant',
    'Material',
    'Volume',
    'Date',
    'SalesTargetGroup',
    'PeriodDiff',
    ]

# %%
data = data[cols]

# %%
data
# Out:
#          Plant           Material  Volume PlannedPeriod SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0    2019-02-01              510
# 1         5M01  AI15570013TARCA20       0    2019-03-01              510
# 2         5M01  AI15570013TARCA20       0    2019-04-01              510
# 3         5M01  AI15570013TARCA20       0    2019-05-01              510
# 4         5M01  AI15570013TARCA20       0    2019-06-01              510
# ...        ...                ...     ...           ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0    2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0    2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0    2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0    2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0    2022-01-01              5A4
#
#           PeriodDiff
# 0                -35
# 1                -34
# 2                -33
# ...

# %%
data.rename(columns={'PlannedPeriod':'Date'}, inplace=True)

# %%
data
# Out:
#          Plant           Material  Volume        Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0  2019-02-01              510
# 1         5M01  AI15570013TARCA20       0  2019-03-01              510
# 2         5M01  AI15570013TARCA20       0  2019-04-01              510
# 3         5M01  AI15570013TARCA20       0  2019-05-01              510
# 4         5M01  AI15570013TARCA20       0  2019-06-01              510
# ...        ...                ...     ...         ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0  2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0  2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0  2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0  2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0  2022-01-01              5A4
#
#           PeriodDiff
# 0                -35
# 1                -34
# 2                -33
# 3                -32
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7363296 entries, 0 to 17180975
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Plant             object
#  1   Material          object
#  2   Volume            int64
#  3   Date              object
#  4   SalesTargetGroup  object
#  5   PeriodDiff        int64
# dtypes: int64(2), object(4)
# memory usage: 393.2+ MB

# %%
data['Date']= pd.to_datetime(data['Date'])

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0 2019-02-01              510
# 1         5M01  AI15570013TARCA20       0 2019-03-01              510
# 2         5M01  AI15570013TARCA20       0 2019-04-01              510
# 3         5M01  AI15570013TARCA20       0 2019-05-01              510
# 4         5M01  AI15570013TARCA20       0 2019-06-01              510
# ...        ...                ...     ...        ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0 2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0 2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0 2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0 2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0 2022-01-01              5A4
#
#           PeriodDiff
# 0                -35
# 1                -34
# 2                -33
# 3                -32
# ...

# %%
data["Date"].dt.year * 12
# Out:
# 0           24228
# 1           24228
# 2           24228
# 3           24228
# 4           24228
#             ...
# 17180971    24252
# 17180972    24252
# 17180973    24252
# 17180974    24252
# 17180975    24264
# Name: Date, Length: 7363296, dtype: int64

# %%
data["time_idx"] = data["Date"].dt.year * 12 + data["Date"].dt.month

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0 2019-02-01              510
# 1         5M01  AI15570013TARCA20       0 2019-03-01              510
# 2         5M01  AI15570013TARCA20       0 2019-04-01              510
# 3         5M01  AI15570013TARCA20       0 2019-05-01              510
# 4         5M01  AI15570013TARCA20       0 2019-06-01              510
# ...        ...                ...     ...        ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0 2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0 2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0 2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0 2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0 2022-01-01              5A4
#
#           PeriodDiff  time_idx
# 0                -35     24230
# 1                -34     24231
# ...

# %%
data["time_idx"] -= data["time_idx"].min()
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0 2019-02-01              510
# 1         5M01  AI15570013TARCA20       0 2019-03-01              510
# 2         5M01  AI15570013TARCA20       0 2019-04-01              510
# 3         5M01  AI15570013TARCA20       0 2019-05-01              510
# 4         5M01  AI15570013TARCA20       0 2019-06-01              510
# ...        ...                ...     ...        ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0 2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0 2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0 2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0 2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0 2022-01-01              5A4
#
#           PeriodDiff  time_idx
# 0                -35         0
# 1                -34         1
# ...

# %%
data["month"] = data.Date.dt.month.astype(str).astype("category")

# %%
data["log_volume"] = np.log(data.Volume + 1e-8)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7363296 entries, 0 to 17180975
# Data columns (total 9 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Plant             object
#  1   Material          object
#  2   Volume            int64
#  3   Date              datetime64[ns]
#  4   SalesTargetGroup  object
#  5   PeriodDiff        int64
#  6   time_idx          int64
#  7   month             category
#  8   log_volume        float64
# dtypes: category(1), datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 512.6+ MB

# %%
data["avg_volume_by_material"] = data.groupby(["time_idx", "Material"], observed=True).Volume.transform("mean")
data["avg_volume_by_plant"] = data.groupby(["time_idx", "Plant"], observed=True).Volume.transform("mean")

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0 2019-02-01              510
# 1         5M01  AI15570013TARCA20       0 2019-03-01              510
# 2         5M01  AI15570013TARCA20       0 2019-04-01              510
# 3         5M01  AI15570013TARCA20       0 2019-05-01              510
# 4         5M01  AI15570013TARCA20       0 2019-06-01              510
# ...        ...                ...     ...        ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0 2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0 2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0 2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0 2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0 2022-01-01              5A4
#
#           PeriodDiff  time_idx month  log_volume  avg_volume_by_material  \
# ...

# %%
data = data.assign(
    timeseries=pd.factorize(list(zip(
        *[data[c].values.tolist() for c in ['Plant', 'Material']]
    )))[0] + 1
)

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0 2019-02-01              510
# 1         5M01  AI15570013TARCA20       0 2019-03-01              510
# 2         5M01  AI15570013TARCA20       0 2019-04-01              510
# 3         5M01  AI15570013TARCA20       0 2019-05-01              510
# 4         5M01  AI15570013TARCA20       0 2019-06-01              510
# ...        ...                ...     ...        ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0 2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0 2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0 2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0 2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0 2022-01-01              5A4
#
#           PeriodDiff  time_idx month  log_volume  avg_volume_by_material  \
# ...

# %%
data.to_csv('processed_for_exploration2.csv')

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 0         5M01  AI15570013TARCA20       0 2019-02-01              510
# 1         5M01  AI15570013TARCA20       0 2019-03-01              510
# 2         5M01  AI15570013TARCA20       0 2019-04-01              510
# 3         5M01  AI15570013TARCA20       0 2019-05-01              510
# 4         5M01  AI15570013TARCA20       0 2019-06-01              510
# ...        ...                ...     ...        ...              ...
# 17180971  5V21  TT38652264TT3RTA0       0 2021-09-01              5A4
# 17180972  5V21  TT38652264TT3RTA0       0 2021-10-01              5A4
# 17180973  5V21  TT38652264TT3RTA0       0 2021-11-01              5A4
# 17180974  5V21  TT38652264TT3RTA0       0 2021-12-01              5A4
# 17180975  5V21  TT38652264TT3RTA0       0 2022-01-01              5A4
#
#           PeriodDiff  time_idx month  log_volume  avg_volume_by_material  \
# ...

# %%
uniques("timeseries")
# Out:
# The number of unique values in column "timeseries" is:  58374
# 37183    1692
# 43491    1656
# 43986    1620
# 38396    1620
# 38422    1620
#          ...
# 23865      36
# 23867      36
# 23870      36
# 23871      36
# 58374      36
# Name: timeseries, Length: 58374, dtype: int64

# %%
data = data.loc[data['timeseries'] == '37183']

# %%
data
# Out:
# Empty DataFrame
# Columns: [Plant, Material, Volume, Date, SalesTargetGroup, PeriodDiff, time_idx, month, log_volume, avg_volume_by_material, avg_volume_by_plant, timeseries]
# Index: []

# %%
data = pd.read_csv('./processed_for_exploration2.csv')

# %%
data
# Out:
#          Unnamed: 0 Plant           Material  Volume        Date  \
# 0                 0  5M01  AI15570013TARCA20       0  2019-02-01
# 1                 1  5M01  AI15570013TARCA20       0  2019-03-01
# 2                 2  5M01  AI15570013TARCA20       0  2019-04-01
# 3                 3  5M01  AI15570013TARCA20       0  2019-05-01
# 4                 4  5M01  AI15570013TARCA20       0  2019-06-01
# ...             ...   ...                ...     ...         ...
# 7363291    17180971  5V21  TT38652264TT3RTA0       0  2021-09-01
# 7363292    17180972  5V21  TT38652264TT3RTA0       0  2021-10-01
# 7363293    17180973  5V21  TT38652264TT3RTA0       0  2021-11-01
# 7363294    17180974  5V21  TT38652264TT3RTA0       0  2021-12-01
# 7363295    17180975  5V21  TT38652264TT3RTA0       0  2022-01-01
#
#         SalesTargetGroup  PeriodDiff  time_idx  month  log_volume  \
# 0                    510         -35         0      2  -18.420681
# ...

# %%
data.loc[data['timeseries'] == 1]
# Out:
#      Unnamed: 0 Plant           Material  Volume        Date SalesTargetGroup  \
# 0             0  5M01  AI15570013TARCA20       0  2019-02-01              510
# 1             1  5M01  AI15570013TARCA20       0  2019-03-01              510
# 2             2  5M01  AI15570013TARCA20       0  2019-04-01              510
# 3             3  5M01  AI15570013TARCA20       0  2019-05-01              510
# 4             4  5M01  AI15570013TARCA20       0  2019-06-01              510
# ..          ...   ...                ...     ...         ...              ...
# 427         955  5M01  AI15570013TARCA20       0  2021-09-01              5B7
# 428         956  5M01  AI15570013TARCA20       0  2021-10-01              5B7
# 429         957  5M01  AI15570013TARCA20       0  2021-11-01              5B7
# 430         958  5M01  AI15570013TARCA20       0  2021-12-01              5B7
# 431         959  5M01  AI15570013TARCA20       0  2022-01-01              5B7
#
# ...

# %%
data.loc[data['timeseries'] == 1].to_csv('processed_for_exploration_timeseries1.csv')
