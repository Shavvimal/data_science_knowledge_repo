# %%
import pandas as pd
import numpy as np
data = pd.read_csv('./dataexport.csv')

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 0            2022-01-01  AI19565015TWICA22  5M01              5B5
# 1            2022-01-01  AI19565015TWICA22  5M01              5B5
# 2            2022-01-01  AI19565015TWICA22  5M01              5B5
# 3            2022-01-01  AI19565015TWICA22  5M01              5B5
# 4            2022-01-01  AI19565015TWICA22  5M01              5B6
# ...                 ...                ...   ...              ...
# 20044523     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044524     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044525     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044526     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044527     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff   FieldID                Field  \
# 0           2022-04-01           3  SLSHDCRC  SalesHeadCorrection
# 1           2021-04-01          -9    ACTSLS      SalesYearMinus1
# 2           2020-04-01         -21    ACTSLS      SalesYearMinus2
# 3           2019-04-01         -33    ACTSLS      SalesYearMinus3
# 4           2022-04-01           3  FNLBSFRC    FinalBaseForecast
# ...                ...         ...       ...                  ...
# 20044523    2023-03-01          14    SLSBDG          SalesBudget
# 20044524    2023-03-01          14  SLSHDCRC  SalesHeadCorrection
# 20044525    2022-03-01           2    ACTSLS      SalesYearMinus1
# 20044526    2021-03-01         -10    ACTSLS      SalesYearMinus2
# 20044527    2020-03-01         -22    ACTSLS      SalesYearMinus3
#
#           FieldContent UpdateBy                     UpdateWhen
# 0                    0    Macro  2022-01-25 22:31:11.460000000
# 1                    0    Macro  2022-01-25 22:31:11.460000000
# 2                    0    Macro  2022-01-25 22:31:11.460000000
# 3                    0    Macro  2022-01-25 22:31:11.460000000
# 4                    0    Macro  2022-01-25 22:31:11.460000000
# ...                ...      ...                            ...
# 20044523             0    Macro  2022-01-25 22:31:11.460000000
# 20044524             0    Macro  2022-01-25 22:31:11.460000000
# 20044525             0    Macro  2022-01-25 22:31:11.460000000
# 20044526             0    Macro  2022-01-25 22:31:11.460000000
# 20044527             0    Macro  2022-01-25 22:31:11.460000000
#
# [20044528 rows x 11 columns]

# %%
data = data.loc[data['FieldID'] == 'ACTSLS']

# %%
data.drop('FieldID', axis=1, inplace=True)
data.drop('Field', axis=1, inplace=True)
data.rename(columns={'FieldContent':'Volume'}, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\ml\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\shav.vimelindiran\Anaconda3\envs\ml\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 1            2022-01-01  AI19565015TWICA22  5M01              5B5
# 2            2022-01-01  AI19565015TWICA22  5M01              5B5
# 3            2022-01-01  AI19565015TWICA22  5M01              5B5
# 8            2022-01-01  AI19565015TWICA22  5M01              5B6
# 9            2022-01-01  AI19565015TWICA22  5M01              5B6
# ...                 ...                ...   ...              ...
# 20044519     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044520     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044525     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044526     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044527     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff  Volume UpdateBy  \
# 1           2021-04-01          -9       0    Macro
# 2           2020-04-01         -21       0    Macro
# 3           2019-04-01         -33       0    Macro
# 8           2021-04-01          -9       0    Macro
# 9           2020-04-01         -21       0    Macro
# ...                ...         ...     ...      ...
# 20044519    2021-02-01         -11       0    Macro
# 20044520    2020-02-01         -23       0    Macro
# 20044525    2022-03-01           2       0    Macro
# 20044526    2021-03-01         -10       0    Macro
# 20044527    2020-03-01         -22       0    Macro
#
#                              UpdateWhen
# 1         2022-01-25 22:31:11.460000000
# 2         2022-01-25 22:31:11.460000000
# 3         2022-01-25 22:31:11.460000000
# 8         2022-01-25 22:31:11.460000000
# 9         2022-01-25 22:31:11.460000000
# ...                                 ...
# 20044519  2022-01-25 22:31:11.460000000
# 20044520  2022-01-25 22:31:11.460000000
# 20044525  2022-01-25 22:31:11.460000000
# 20044526  2022-01-25 22:31:11.460000000
# 20044527  2022-01-25 22:31:11.460000000
#
# [8590512 rows x 9 columns]

# %%
def prCyan(skk): print("\033[96m {}\033[00m" .format(skk))

def uniques(category):    
    category_counts = data[category].value_counts()
    print("The number of unique values in column \"" + str(category) + "\" is: ", end = '')
    prCyan(str(len(category_counts)))
    category_counts.plot(kind='bar')

def uniques_nograph(category):    
    category_counts = data[category].value_counts()
    print("The number of unique values in column \"" + str(category) + "\" is: ", end = '')
    prCyan(str(len(category_counts)))
    return(category_counts)

# %%
data.columns
# Out:
# Index(['PlanningPeriod', 'Material', 'Plant', 'SalesTargetGroup',
#        'PlannedPeriod', 'PeriodDiff', 'Volume', 'UpdateBy', 'UpdateWhen'],
#       dtype='object')

# %%
uniques("UpdateBy")
# Out:
# The number of unique values in column "UpdateBy" is:  1

# %%
data.drop('UpdateBy', axis=1, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\ml\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.columns
# Out:
# Index(['PlanningPeriod', 'Material', 'Plant', 'SalesTargetGroup',
#        'PlannedPeriod', 'PeriodDiff', 'Volume', 'UpdateWhen'],
#       dtype='object')

# %%
uniques("UpdateWhen")
# Out:
# The number of unique values in column "UpdateWhen" is:  1

# %%
data.drop('UpdateWhen', axis=1, inplace=True)

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 1            2022-01-01  AI19565015TWICA22  5M01              5B5
# 2            2022-01-01  AI19565015TWICA22  5M01              5B5
# 3            2022-01-01  AI19565015TWICA22  5M01              5B5
# 8            2022-01-01  AI19565015TWICA22  5M01              5B6
# 9            2022-01-01  AI19565015TWICA22  5M01              5B6
# ...                 ...                ...   ...              ...
# 20044519     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044520     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044525     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044526     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044527     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff  Volume
# 1           2021-04-01          -9       0
# 2           2020-04-01         -21       0
# 3           2019-04-01         -33       0
# 8           2021-04-01          -9       0
# 9           2020-04-01         -21       0
# ...                ...         ...     ...
# 20044519    2021-02-01         -11       0
# 20044520    2020-02-01         -23       0
# 20044525    2022-03-01           2       0
# 20044526    2021-03-01         -10       0
# 20044527    2020-03-01         -22       0
#
# [8590512 rows x 7 columns]

# %%
uniques("Volume")
# Out:
# The number of unique values in column "Volume" is:  2659

# %%
data
# Out:
#          PlanningPeriod           Material Plant SalesTargetGroup  \
# 1            2022-01-01  AI19565015TWICA22  5M01              5B5
# 2            2022-01-01  AI19565015TWICA22  5M01              5B5
# 3            2022-01-01  AI19565015TWICA22  5M01              5B5
# 8            2022-01-01  AI19565015TWICA22  5M01              5B6
# 9            2022-01-01  AI19565015TWICA22  5M01              5B6
# ...                 ...                ...   ...              ...
# 20044519     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044520     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044525     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044526     2022-01-01  TT38652264TT3RTA0  5V21              5A4
# 20044527     2022-01-01  TT38652264TT3RTA0  5V21              5A4
#
#          PlannedPeriod  PeriodDiff  Volume
# 1           2021-04-01          -9       0
# 2           2020-04-01         -21       0
# 3           2019-04-01         -33       0
# 8           2021-04-01          -9       0
# 9           2020-04-01         -21       0
# ...                ...         ...     ...
# 20044519    2021-02-01         -11       0
# 20044520    2020-02-01         -23       0
# 20044525    2022-03-01           2       0
# 20044526    2021-03-01         -10       0
# 20044527    2020-03-01         -22       0
#
# [8590512 rows x 7 columns]

# %%
uniques("PlanningPeriod")
# Out:
# The number of unique values in column "PlanningPeriod" is:  1

# %%
data.drop('PlanningPeriod', axis=1, inplace=True)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\ml\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data
# Out:
#                    Material Plant SalesTargetGroup PlannedPeriod  PeriodDiff  \
# 1         AI19565015TWICA22  5M01              5B5    2021-04-01          -9
# 2         AI19565015TWICA22  5M01              5B5    2020-04-01         -21
# 3         AI19565015TWICA22  5M01              5B5    2019-04-01         -33
# 8         AI19565015TWICA22  5M01              5B6    2021-04-01          -9
# 9         AI19565015TWICA22  5M01              5B6    2020-04-01         -21
# ...                     ...   ...              ...           ...         ...
# 20044519  TT38652264TT3RTA0  5V21              5A4    2021-02-01         -11
# 20044520  TT38652264TT3RTA0  5V21              5A4    2020-02-01         -23
# 20044525  TT38652264TT3RTA0  5V21              5A4    2022-03-01           2
# 20044526  TT38652264TT3RTA0  5V21              5A4    2021-03-01         -10
# 20044527  TT38652264TT3RTA0  5V21              5A4    2020-03-01         -22
#
#           Volume
# 1              0
# 2              0
# 3              0
# 8              0
# 9              0
# ...          ...
# 20044519       0
# 20044520       0
# 20044525       0
# 20044526       0
# 20044527       0
#
# [8590512 rows x 6 columns]

# %%
cols = data.columns.tolist()

# %%
cols
# Out:
# ['Material',
#  'Plant',
#  'SalesTargetGroup',
#  'PlannedPeriod',
#  'PeriodDiff',
#  'Volume']

# %%
cols = [
    'Plant',
    'Material',
    'Volume',
    'Date',
    'SalesTargetGroup',
    'PeriodDiff',
    ]

# %%
data = data[cols]

# %%
data
# Out:
#          Plant           Material  Volume PlannedPeriod SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0    2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0    2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0    2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0    2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0    2020-04-01              5B6
# ...        ...                ...     ...           ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0    2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0    2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0    2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0    2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0    2020-03-01              5A4
#
#           PeriodDiff
# 1                 -9
# 2                -21
# 3                -33
# 8                 -9
# 9                -21
# ...              ...
# 20044519         -11
# 20044520         -23
# 20044525           2
# 20044526         -10
# 20044527         -22
#
# [8590512 rows x 6 columns]

# %%
data.rename(columns={'PlannedPeriod':'Date'}, inplace=True)

# %%
data
# Out:
#          Plant           Material  Volume        Date SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0  2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0  2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0  2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0  2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0  2020-04-01              5B6
# ...        ...                ...     ...         ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0  2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0  2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0  2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0  2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0  2020-03-01              5A4
#
#           PeriodDiff
# 1                 -9
# 2                -21
# 3                -33
# 8                 -9
# 9                -21
# ...              ...
# 20044519         -11
# 20044520         -23
# 20044525           2
# 20044526         -10
# 20044527         -22
#
# [8590512 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8590512 entries, 1 to 20044527
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Plant             object
#  1   Material          object
#  2   Volume            int64
#  3   Date              object
#  4   SalesTargetGroup  object
#  5   PeriodDiff        int64
# dtypes: int64(2), object(4)
# memory usage: 458.8+ MB

# %%
data['Date']= pd.to_datetime(data['Date'])

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0 2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0 2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0 2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0 2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0 2020-04-01              5B6
# ...        ...                ...     ...        ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0 2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0 2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0 2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0 2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0 2020-03-01              5A4
#
#           PeriodDiff
# 1                 -9
# 2                -21
# 3                -33
# 8                 -9
# 9                -21
# ...              ...
# 20044519         -11
# 20044520         -23
# 20044525           2
# 20044526         -10
# 20044527         -22
#
# [8590512 rows x 6 columns]

# %%
data["Date"].dt.year * 12
# Out:
# 1           24252
# 2           24240
# 3           24228
# 8           24252
# 9           24240
#             ...
# 20044519    24252
# 20044520    24240
# 20044525    24264
# 20044526    24252
# 20044527    24240
# Name: Date, Length: 8590512, dtype: int64

# %%
data["time_idx"] = data["Date"].dt.year * 12 + data["Date"].dt.month

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0 2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0 2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0 2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0 2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0 2020-04-01              5B6
# ...        ...                ...     ...        ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0 2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0 2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0 2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0 2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0 2020-03-01              5A4
#
#           PeriodDiff  time_idx
# 1                 -9     24256
# 2                -21     24244
# 3                -33     24232
# 8                 -9     24256
# 9                -21     24244
# ...              ...       ...
# 20044519         -11     24254
# 20044520         -23     24242
# 20044525           2     24267
# 20044526         -10     24255
# 20044527         -22     24243
#
# [8590512 rows x 7 columns]

# %%
data["time_idx"] -= data["time_idx"].min()
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0 2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0 2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0 2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0 2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0 2020-04-01              5B6
# ...        ...                ...     ...        ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0 2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0 2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0 2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0 2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0 2020-03-01              5A4
#
#           PeriodDiff  time_idx
# 1                 -9        26
# 2                -21        14
# 3                -33         2
# 8                 -9        26
# 9                -21        14
# ...              ...       ...
# 20044519         -11        24
# 20044520         -23        12
# 20044525           2        37
# 20044526         -10        25
# 20044527         -22        13
#
# [8590512 rows x 7 columns]

# %%
data["month"] = data.Date.dt.month.astype(str).astype("category")

# %%
data["log_volume"] = np.log(data.Volume + 1e-8)
# Out:
# C:\Users\shav.vimelindiran\Anaconda3\envs\ml\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8590512 entries, 1 to 20044527
# Data columns (total 9 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Plant             object
#  1   Material          object
#  2   Volume            int64
#  3   Date              datetime64[ns]
#  4   SalesTargetGroup  object
#  5   PeriodDiff        int64
#  6   time_idx          int64
#  7   month             category
#  8   log_volume        float64
# dtypes: category(1), datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 598.1+ MB

# %%
data["avg_volume_by_material"] = data.groupby(["time_idx", "Material"], observed=True).Volume.transform("mean")
data["avg_volume_by_plant"] = data.groupby(["time_idx", "Plant"], observed=True).Volume.transform("mean")

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0 2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0 2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0 2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0 2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0 2020-04-01              5B6
# ...        ...                ...     ...        ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0 2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0 2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0 2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0 2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0 2020-03-01              5A4
#
#           PeriodDiff  time_idx month  log_volume  avg_volume_by_material  \
# 1                 -9        26     4  -18.420681                0.142857
# 2                -21        14     4  -18.420681                0.142857
# 3                -33         2     4  -18.420681               -0.392857
# 8                 -9        26     4  -18.420681                0.142857
# 9                -21        14     4  -18.420681                0.142857
# ...              ...       ...   ...         ...                     ...
# 20044519         -11        24     2  -18.420681                0.000000
# 20044520         -23        12     2  -18.420681                0.000000
# 20044525           2        37     3  -18.420681                0.000000
# 20044526         -10        25     3  -18.420681                0.000000
# 20044527         -22        13     3  -18.420681                0.000000
#
#           avg_volume_by_plant
# 1                    1.739197
# 2                    2.257877
# 3                    3.653115
# 8                    1.739197
# 9                    2.257877
# ...                       ...
# 20044519             0.657915
# 20044520             0.953934
# 20044525             0.000000
# 20044526             0.679336
# 20044527             0.523223
#
# [8590512 rows x 11 columns]

# %%
data = data.assign(
    timeseries=pd.factorize(list(zip(
        *[data[c].values.tolist() for c in ['Plant', 'Material']]
    )))[0] + 1
)

# %%
data
# Out:
#          Plant           Material  Volume       Date SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0 2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0 2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0 2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0 2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0 2020-04-01              5B6
# ...        ...                ...     ...        ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0 2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0 2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0 2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0 2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0 2020-03-01              5A4
#
#           PeriodDiff  time_idx month  log_volume  avg_volume_by_material  \
# 1                 -9        26     4  -18.420681                0.142857
# 2                -21        14     4  -18.420681                0.142857
# 3                -33         2     4  -18.420681               -0.392857
# 8                 -9        26     4  -18.420681                0.142857
# 9                -21        14     4  -18.420681                0.142857
# ...              ...       ...   ...         ...                     ...
# 20044519         -11        24     2  -18.420681                0.000000
# 20044520         -23        12     2  -18.420681                0.000000
# 20044525           2        37     3  -18.420681                0.000000
# 20044526         -10        25     3  -18.420681                0.000000
# 20044527         -22        13     3  -18.420681                0.000000
#
#           avg_volume_by_plant  timeseries
# 1                    1.739197           1
# 2                    2.257877           1
# 3                    3.653115           1
# 8                    1.739197           1
# 9                    2.257877           1
# ...                       ...         ...
# 20044519             0.657915       58374
# 20044520             0.953934       58374
# 20044525             0.000000       58374
# 20044526             0.679336       58374
# 20044527             0.523223       58374
#
# [8590512 rows x 12 columns]

# %%
data.to_csv('processed_for_exploration.csv')

# %%
data
# Out:
#          Plant           Material  Volume PlannedPeriod SalesTargetGroup  \
# 1         5M01  AI19565015TWICA22       0    2021-04-01              5B5
# 2         5M01  AI19565015TWICA22       0    2020-04-01              5B5
# 3         5M01  AI19565015TWICA22       0    2019-04-01              5B5
# 8         5M01  AI19565015TWICA22       0    2021-04-01              5B6
# 9         5M01  AI19565015TWICA22       0    2020-04-01              5B6
# ...        ...                ...     ...           ...              ...
# 20044519  5V21  TT38652264TT3RTA0       0    2021-02-01              5A4
# 20044520  5V21  TT38652264TT3RTA0       0    2020-02-01              5A4
# 20044525  5V21  TT38652264TT3RTA0       0    2022-03-01              5A4
# 20044526  5V21  TT38652264TT3RTA0       0    2021-03-01              5A4
# 20044527  5V21  TT38652264TT3RTA0       0    2020-03-01              5A4
#
#           PeriodDiff  time_idx month  log_volume  avg_volume_by_material  \
# 1                 -9        26     4  -18.420681                0.142857
# 2                -21        14     4  -18.420681                0.142857
# 3                -33         2     4  -18.420681               -0.392857
# 8                 -9        26     4  -18.420681                0.142857
# 9                -21        14     4  -18.420681                0.142857
# ...              ...       ...   ...         ...                     ...
# 20044519         -11        24     2  -18.420681                0.000000
# 20044520         -23        12     2  -18.420681                0.000000
# 20044525           2        37     3  -18.420681                0.000000
# 20044526         -10        25     3  -18.420681                0.000000
# 20044527         -22        13     3  -18.420681                0.000000
#
#           avg_volume_by_plant
# 1                    1.739197
# 2                    2.257877
# 3                    3.653115
# 8                    1.739197
# 9                    2.257877
# ...                       ...
# 20044519             0.657915
# 20044520             0.953934
# 20044525             0.000000
# 20044526             0.679336
# 20044527             0.523223
#
# [8590512 rows x 11 columns]
