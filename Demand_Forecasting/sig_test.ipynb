# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    y = 1 / (1 + np.exp(-x))
    return y


xs = list(range(-15, 15, 1))
ys = []
for x in xs:
    y = sigmoid(sigmoid(x))
    ys.append(y)


plt.grid()
plt.plot(xs, ys)
plt.show()
